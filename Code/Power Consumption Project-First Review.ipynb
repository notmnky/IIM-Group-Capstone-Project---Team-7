# %% [markdown]
# ## Read Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.tsa.seasonal import seasonal_decompose
plt.rcParams['figure.figsize'] = [15, 8]

# %% [markdown]
# ## Read the timeseries data and define index

# %%
os.chdir('C:\\Users\\Akash Deepak\\Desktop\\Project')
data = pd.read_csv("TS Data.csv",index_col=[0],parse_dates=[0])

# %% [markdown]
# ## Data Exploration on daily data

# %%
data.head()
# Out:
#              Usage
# Date
# 2015-04-01  3734.0
# 2015-04-02  3709.0
# 2015-04-03  3188.0
# 2015-04-04  3721.0
# 2015-04-05  3685.0

# %%
data["Usage"].plot()

# %% [markdown]
# ## Resample the data for monthly data

# %%
data=data.resample('1M').mean()

# %% [markdown]
# ## Data Exploration on resampled data

# %%
data.head()
# Out:
#                   Usage
# Date
# 2015-04-30  4109.700347
# 2015-05-31  5457.000336
# 2015-06-30  5335.030528
# 2015-07-31  6506.275874
# 2015-08-31  6637.765457

# %%
data.tail()
# Out:
#               Usage
# Date
# 2021-03-27  5216.84
# 2021-03-28  4302.12
# 2021-03-29  3932.78
# 2021-03-30  4740.36
# 2021-03-31  4945.26

# %%
data.shape
# Out:
# (72, 1)

# %% [markdown]
# ## Visualization of data usage

# %%
data["Usage"].plot()

# %% [markdown]
# ## Seasonal Decompose of timeseries

# %%
result_m= seasonal_decompose(data.iloc[:50], model='multiplicative',period=12)
result_m.plot()
plt.show()
